# %%
import argparse
import random
import sys
import math
import logging

import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import cm, pyplot as plt

# %%
summary = pd.read_csv(f"../out/summary.csv")

# %%
summary.head()
# Out:
#    aliveCount  totalCount  generations  treeDepth  nodeCount  leafCount  \
# 0       29492     2460080        33947          3         86         76
# 1       29676     2509991        31234          5         85         65
# 2      196970     2490959        25348          4         71         61
# 3      120313     2498084        24867          3         59         49
# 4      186430     2474492        20058          3         59         50
#
#    branching  subcloneTotal  subcloneSelect  clonalDiversityFiltered  \
# 0   1.118421          10000              86                 3.807412
# 1   1.292308          10000              85                 7.383556
# 2   1.147541          10002              71                 5.063290
# 3   1.183674          10005              59                 3.165443
# 4   1.160000          10007              59                 2.214102
#
#    clonalDiversity  treeBalance  treeBalanceFiltered  meanDriversPerCell  \
# 0                0            0             0.236281                   0
# 1                0            0             0.433496                   0
# 2                0            0             0.216091                   0
# 3                0            0             0.202206                   0
# 4                0            0             0.174437                   0
#
#    meanDriversPerCellFiltered
# 0                    0.000000
# 1                    0.011018
# 2                    0.814264
# 3                    0.415705
# 4                    0.722089

# %%
plt.ylabel("clonalDiversityFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["clonalDiversityFiltered"])

# %%
plt.ylabel("meanDriversPerCellFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["meanDriversPerCellFiltered"])

# %%
plt.ylabel("treeBalanceFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["treeBalanceFiltered"])
