# %%
import argparse
import random
import sys
import math
import logging

import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import cm, pyplot as plt

# %%
timestamp = "22_03_22_17_00_24"
summary = pd.read_csv(f"../out/{timestamp}/summary.csv")

# %%
summary.head()
# Out:
#    aliveCount  totalCount  generations  treeDepth  nodeCount  leafCount  \
# 0           0           4         8354          1          4          3
# 1         143         186        10000          2         21         18
# 2        1633        1964        10000          2         16         14
# 3       72061       80074        10000          3         25         21
# 4           0           3         3258          1          3          2
#
#    branching  subcloneTotal  subcloneSelect  clonalDiversityFiltered  \
# 0   1.000000              4               4                 4.000000
# 1   1.111111             34              21                 1.680177
# 2   1.071428            159              16                 2.885285
# 3   1.142857           1244              25                 3.177547
# 4   1.000000              3               3                 3.000000
#
#    clonalDiversity  treeBalance  treeBalanceFiltered  meanDriversPerCell  \
# ...

# %%
plt.scatter(range(len(summary)), summary["aliveCount"])

# %%
plt.scatter(range(len(summary)), summary["totalCount"])
