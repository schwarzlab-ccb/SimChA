# %%
import argparse
import random
import sys
import math
import logging

import numpy as np
import pandas as pd
from matplotlib import cm, pyplot as plt

# %%
summary = pd.read_csv(f"../out/summary.csv")

# %%
summary.head()
# Out:
#    aliveCount  totalCount  generations  treeDepth  nodeCount  leafCount  \
# 0       91235      498532        63483          4         72         57
# 1        3147       95739       100000          6        170        119
# 2        9503      172691       100000          4        143         95
# 3         399       64592       100000          5        170        120
# 4        3836      125518       100000          4        165        125
#
#    branching  subcloneTotal  subcloneSelect  clonalDiversity  \
# 0   1.245614          10000              72                0
# 1   1.420168           1887             170                0
# 2   1.494737           3372             143                0
# 3   1.408333           1254             170                0
# 4   1.312000           2513             166                0
#
#    clonalDiversityFiltered  treeBalance  treeBalanceFiltered  \
# 0                 2.683840            0             0.107750
# 1                 5.920075            0             0.357130
# 2                 7.356719            0             0.352587
# 3                 3.942440            0             0.392983
# 4                 5.778832            0             0.366030
#
#    meanDriversPerCell  meanDriversPerCellFiltered
# 0                   0                    1.041351
# 1                   0                    0.208110
# 2                   0                    0.198247
# 3                   0                    0.000000
# 4                   0                    0.232732

# %%
plt.ylabel("clonalDiversityFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["clonalDiversityFiltered"])

# %%
plt.ylabel("meanDriversPerCellFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["meanDriversPerCellFiltered"])

# %%
plt.ylabel("treeBalanceFiltered")
plt.xlabel("run ID")
plt.scatter(range(1, len(summary) +1), summary["treeBalanceFiltered"])
