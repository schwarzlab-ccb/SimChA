# %%
import argparse
import random
import sys
import math
import logging

import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import cm, pyplot as plt

# %%
vaf = pd.read_csv("../out/vaf.csv")

# %%
vaf.head(38)
# Out:
#       id      pop           vaf
# 0      0  6643398  6.540812e-01
# 1      5     1388  1.366567e-04
# 2      8     2584  2.544099e-04
# 3     17        4  3.938233e-07
# 4     31        4  3.938233e-07
# 5     41        2  1.969117e-07
# 6     57        1  9.845583e-08
# 7    119      264  2.599234e-05
# 8    138       37  3.642866e-06
# 9    206        5  4.922791e-07
# 10   231        6  5.907350e-07
# 11     1  6500955  6.400569e-01
# 12    23        1  9.845583e-08
# 13    46        2  1.969117e-07
# 14    48        1  9.845583e-08
# 15   139  6495278  6.394980e-01
# 16   383      547  5.385534e-05
# 17   533     1115  1.097782e-04
# 18  1786    35636  3.508572e-03
# 19     2        1  9.845583e-08
# 20     3     3696  3.638927e-04
# 21     4        2  1.969117e-07
# 22     6        5  4.922791e-07
# 23     7   121830  1.199487e-02
# 24   430   116212  1.144175e-02
# 25     9        3  2.953675e-07
# 26    10        2  1.969117e-07
# 27    11        2  1.969117e-07
# ...

# %%
plt.xlim([0.0,1.0])
plt.hist(vaf["vaf"], 20, weights=vaf["pop"])
# Out:
# (array([ 2526332.,        0.,        0.,        0.,        0.,  1687100.,
#                0.,        0.,        0.,        0.,        0.,        0.,
#                0.,        0.,        0., 10481519.,  5395677.,        0.,
#                0., 19639631.]),
#  array([9.84558300e-08, 3.27041535e-02, 6.54082086e-02, 9.81122637e-02,
#         1.30816319e-01, 1.63520374e-01, 1.96224429e-01, 2.28928484e-01,
#         2.61632539e-01, 2.94336594e-01, 3.27040649e-01, 3.59744704e-01,
#         3.92448759e-01, 4.25152814e-01, 4.57856870e-01, 4.90560925e-01,
#         5.23264980e-01, 5.55969035e-01, 5.88673090e-01, 6.21377145e-01,
#         6.54081200e-01]),
#  <BarContainer object of 20 artists>)

# %%
vaf["vaf"]
# Out:
# 0      6.540812e-01
# 1      1.366567e-04
# 2      2.544099e-04
# 3      3.938233e-07
# 4      3.938233e-07
#            ...
# 238    1.166406e-03
# 239    1.034475e-03
# 240    9.999174e-04
# 241    9.769772e-04
# 242    9.992282e-04
# Name: vaf, Length: 243, dtype: float64

# %%
vaf["pop"]
# Out:
# 0      6643398
# 1         1388
# 2         2584
# 3            4
# 4            4
#         ...
# 238      11847
# 239      10507
# 240      10156
# 241       9923
# 242      10149
# Name: pop, Length: 243, dtype: int64

# %%
summary = pd.read_csv("../out/summary.csv")

# %%
plt.plot(summary["aliveCount"])
plt.xlabel("")
