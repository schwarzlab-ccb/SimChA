# %%
import matplotlib.pyplot as plt
import math

# %%
plt.pie([100])
# Out:
# ([<matplotlib.patches.Wedge at 0x218c0610d30>],
#  [Text(-1.1, 1.3471114790620887e-16, '')])

# %%
plt.pie([0, 5])
# Out:
# ([<matplotlib.patches.Wedge at 0x218c27c5520>,
# ...
#  [Text(1.1, 0.0, ''), Text(-1.1, 1.3471114790620887e-16, '')])

# %%
plt.pie([40, 30, 15, 10])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc090258c50>,
# ...
#  [Text(0.2700340253456176, 1.06634029519457, ''),
#   Text(-0.9674211366466228, -0.5235421132720431, ''),
#   Text(0.44186488769512783, -1.0073506941587782, ''),
#   Text(1.040398931550063, -0.3571695160977312, '')])

# %%
plt.pie([0,30,0,0, 5])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc090165350>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(-0.9910657674599292, 0.4772720865178076, ''),
#   Text(0.6858388280562517, -0.8600145940217686, ''),
#   Text(0.6858388280562517, -0.8600145940217686, ''),
#   Text(0.9910657898026469, -0.4772720401226704, '')])

# %%
plt.pie([0,0,0,30,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc0900c8690>,
# ...
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(-1.1, 1.3471114790620887e-16, ''),
#   Text(1.1, -2.6942229581241775e-16, '')])

# %%
math.log(100)
# Out:
# 4.605170185988092
